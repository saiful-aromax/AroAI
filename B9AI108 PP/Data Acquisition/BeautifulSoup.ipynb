# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url='https://www.ebay.ie/sch/i.html?_from=R40&_nkw=table&_sacat=0&_pgn=2'

# %%
resp=requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'<!DOCTYPE html><!--[if IE 9]><html class="ie9" lang="en"><![endif]--><!--[if gt IE 9]><!--><html lang="en"><!--<![endif]--><!--M#s0-1--><noscript class=x-page-config></noscript><!--M/--><head><meta http-equiv=X-UA-Compatible content=IE=edge><script>"use strict";if(window.PerformanceObserver&&performance&&performance.mark&&performance.getEntriesByName){window.SRP=window.SRP||{};var paintObserver=new window.PerformanceObserver(function(e){var r=e.getEntries();if(r.sort(function(e,r){return e.startTime-r.startTime}),r&&!(r.length<2)){var n=r[1].startTime;window.SRP.TTI_TIMER={lastInteractiveWindow:n};var t=new window.PerformanceObserver(function(e){for(var r=e.getEntries(),i=0,a=r.length;i<a;i++)r[i].startTime-n>=5e3&&(window.SRP.TTI_TIMER.timeToInteract=n,t.disconnect()),n=r[i].startTime+r[i].duration,window.SRP.TTI_TIMER.lastInteractiveWindow=n});t.observe({entryTypes:["longtask"]}),paintObserver.disconnect()}});paintObserver.observe({entryTypes:["paint"]})};</script><meta name="description" content="Find great deals on eBay for table. Shop with confidence." /><title>table | eBay</title><meta name="referrer" content="unsafe-url" /><meta name="y_key" content="f442f1bbcf3cfb26" /><meta name="msvalidate.01" content="34E98E6F27109BE1A9DCF19658EEEE33" /><link rel="preconnect" href="https://ir.ebaystatic.com" /><link rel="canonical" href="https://www.ebay.ie/sch/i.html?_nkw=table" /><link href="https://i.ebayimg.com" rel="preconnect" /><meta name="google-site-verification" content="Xm73iYR54M-bc79KIOupVjMY5J3u_QiWH_d1JKsBTYs" /><meta property="fb:app_id" content="102628213125203" /><!-- NGMARS SIGNATURE --><link rel=dns-prefetch href=//i.ebayimg.com><link rel=dns-prefetch href=//ir.ebaystatic.com><link rel=dns-prefetch href=//rover.ebay.com><link rel=dns-prefetch href=//svcs.ebay.com><link rel=dns-prefetch href=//pulsar.ebay.com><link rel=dns-prefetch href=//www.google.com/ ><link rel=dns-prefetch href=//tpc.googlesyndication.com><link rel=dns-prefetch href=//securepubads.g.doubleclick.net><meta name=viewport content="width=device-width, initial-scale=1, minimum-scale=1"><link rel="dns-prefetch" href="//ir.ebaystatic.com"><link rel="dns-prefetch" href="//secureir.ebaystatic.com"><link rel="dns-prefetch" href="//i.ebayimg.com"><link rel="dns-prefetch" href="//rover.ebay.com"><script>$ssgST=new Date().getTime();!function(){if("PerformanceLongTaskTiming" in window){var g=window.__tti={e:[]};g.o=new PerformanceObserver(function(l){g.e=g.e.concat(l.getEntries())});g.o.observe({entryTypes:["longtask"]})}}();</script><link rel="stylesheet" type="text/css" href="https://ir.ebaystatic.com/rs/v/ixgcx2sdpy5ajduqrxqgqg3e3mb.css?proc=DU:N"><link rel=stylesheet href=https://ir.ebaystatic.com/rs/c/inception-c_N4m3mV.css>\n<link rel=stylesheet href=https://ir.ebaystatic.com/rs/c/search-page-large-RF_CpZBn.css><!--M#s0-4-9--><noscript data-marko-key="@_wbind s0-4-9" id=s0-4-9></noscript><!--M/--><style type=text/css>\n    :root {\n        --sd-s-x59m834: inline;\n        --sd-s-46og274: none;\n        --p4-s-x59m834: 100%;\n        --p4-s-46og274: 98%;\n    }\n    span.s-x59m834 {\n        display: inline;\n    }\n    span.s-46og274 {\n        display: none;\n    }\n    span.s-hpt2274 {\n        position: absolute;\n        left: -2000px;\n        top: auto;\n        width: 1px;\n        height: 1px;\n        overflow: hidden;\n    }\n    .s-item__pl-on-bottom span.s-46og274_s-x59m834,\n    .s-item__pl-on-bottom span.s-x59m834_s-46og274 {\n        position: absolute;\n        bottom: 0;\n    }\n</style><script>(()=>{let p=CSSStyleDeclaration.prototype;let v="getPropertyValue";p.___getPropertyValue=p[v];p[v]=function(a){return this[a]?this[a]:this.___getPropertyValue(a)};Object.defineProperties(p,{textShadow:{get:b},"text-shadow":{get:b}});function b(){return this.getPropertyValue("--s-x59m834")?"rgba(0, 0, 0, 0) 0px 0px 0px":this.___getPropertyValue("text-shadow")}})()</script><style>\n        span.s-46og274_s-x59m834,\n        span.s-x59m834_s-46o ...

# %%
soup=BeautifulSoup(resp.content)

# %%
ul=soup.find('ul',{'class':"srp-results srp-list clearfix"}) #<ul class="srp-results srp-list clearfix">

# %%
items=ul.find_all('li',{'class':"s-item s-item__pl-on-bottom"}) #<li class="s-item s-item__pl-on-bottom"

# %%
len(items)
# Out:
# 74

# %%
info=[]
for item in items:
  record={}
  # record['title']=(item.find('h3',{'class':"s-item__title"}).text)
  record['condition']=item.find('div',{'class':"s-item__subtitle"}).text
  record['price']=float(item.find('span',{'class':"s-item__price"}).text.replace('EUR ','').replace(',','').split(' to ')[0])
  info.append(record)

# %%
items[0].find('div',{'class':"s-item__detail s-item__detail--primary"}).text.replace('EUR ','')
# Out:
# '59.92'

# %%
ebaydf=pd.json_normalize(info)

# %%
ebaydf.describe()
# Out:
#              price
# count    65.000000
# mean   1604.831385
# std    2411.177715
# min      20.990000
# 25%     249.990000
# 50%     384.850000
# 75%    1330.330000
# max    9639.840000

# %%
ebaydf[ebaydf['price']>2000]
# Out:
#                                                 title  condition    price
# 35  Live Edge Elm Slab Cookie Table with Antiqued ...  Brand new  2262.52
# 45  Beautiful Black Marble Hallway Table Top Flora...  Brand new  9639.84
# 46  54 Inches Luxurious Pattern Dining Table Top M...  Brand new  8102.19
# 47  40 Inches Marble Hallway Table Top with Lapis ...  Brand new  4941.49
# 48  48" White Marble Dining Table Top Inlay Carnel...  Brand new  7609.36
# 49  48 Inches Marble Hallway Table Top Black Patio...  Brand new  5618.32
# 50  42 Inches Octagon Shape Hallway Table Top Marb...  Brand new  5237.19
# 51  48 Inches Black Patio Dining Table Top Marble ...  Brand new  5342.33
# 52  50 Inches Marble Hallway Table Top Black Resta...  Brand new  6111.15
# 53  48 Inches Black Hallway Table Marble Dinning T...  Brand new  5191.19
# 54  50 Inches Marble Dining Table Top Black Hallwa...  Brand new  5539.46
# 57  36 x 72 Inches Black Rectangle Hallway Table T...  Brand new  7182.24
# 58  Marquetry Art with Gemstones Coffee Table Marb...  Brand new  4021.53
# 59  42 Inches Black Marble Inlay Table Top Round D...  Brand new  4376.37
# 60  42 Inches Marble Dining Table Top Unique Black...  Brand new  3305.28
