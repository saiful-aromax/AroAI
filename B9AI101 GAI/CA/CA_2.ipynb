# %% [markdown]
# # Apply of the CRISP-DM data mining methodology to analyse the data
#
# In this notebook we're going to apply the steps of the CRISP-DM data mining methodology to analyse the data
#
# The dataset we choose for this project: Stackoverflow. Link: https://demo.neo4jlabs.com:7473/browser/?dbms=neo4j://stackoverflow@demo.neo4jlabs.com&db=stackoverflow

# %% [markdown]
# # Installing necessary libraries

# %%
# !pip install py2neo pandas
# !pip install py2neo pandas matplotlib
# Out:
# Requirement already satisfied: py2neo in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (2021.2.3)
# Requirement already satisfied: pandas in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (1.5.3)
# Requirement already satisfied: pansi>=2020.7.3 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (2020.7.3)
# Requirement already satisfied: urllib3 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (1.26.15)
# Requirement already satisfied: interchange~=2021.0.4 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (2021.0.4)
# Requirement already satisfied: six>=1.15.0 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (1.16.0)
# Requirement already satisfied: certifi in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (2022.12.7)
# Requirement already satisfied: packaging in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (23.0)
# Requirement already satisfied: monotonic in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (1.6)
# Requirement already satisfied: pygments>=2.0.0 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (2.14.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: py2neo in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (2021.2.3)
# Requirement already satisfied: pandas in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (3.7.1)
# Requirement already satisfied: packaging in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (23.0)
# Requirement already satisfied: certifi in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (2022.12.7)
# Requirement already satisfied: urllib3 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (1.26.15)
# Requirement already satisfied: six>=1.15.0 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (1.16.0)
# Requirement already satisfied: pygments>=2.0.0 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (2.14.0)
# Requirement already satisfied: interchange~=2021.0.4 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (2021.0.4)
# Requirement already satisfied: monotonic in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (1.6)
# Requirement already satisfied: pansi>=2020.7.3 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from py2neo) (2020.7.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)

# %% [markdown]
# # Loading necessary libraries

# %%
from py2neo import Graph

import pandas as pd

import matplotlib 
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
pd.set_option('display.float_format', lambda x: '%.3f' % x)

import pandas as pd
from collections import Counter
# from sklearn.ensemble import RandomForestClassifier

# from sklearn.metrics import recall_score
# from sklearn.metrics import precision_score
# from sklearn.metrics import accuracy_score
# from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Section-1: Loading the database into our local neo4j database
# In this section, at first, we created a local database into our Neo4j Desktop named: stackoverflowdb. We choose the db version: 4.1.0
#
# Then apply the following credentials to connnect to our local database:

# %%
graph = Graph("bolt://localhost:7687", auth=("neo4j", "0987654321"))

# %% [markdown]
# After that, we applied the following 7 queries one by one, in order to copy the live data into our local databae.
# The link of the live database: https://demo.neo4jlabs.com:7473/browser/?dbms=neo4j://stackoverflow@demo.neo4jlabs.com&db=stackoverflow

# %%
query = """
WITH "https://api.stackexchange.com/2.2/questions?pagesize=100&order=desc&sort=creation&tagged=neo4j&site=stackoverflow&filter=!5-i6Zw8Y)4W7vpy91PMYsKM-k9yzEsSC1_Uxlf" AS url
CALL apoc.load.json(url) YIELD value

UNWIND value.items AS q

MERGE (question:Question {id:q.question_id})
  ON CREATE SET question.title = q.title, question.share_link = q.share_link, question.favorite_count = q.favorite_count, question.creation_date = q.creation_date
"""
graph.run(query).to_data_frame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query = """
WITH "https://api.stackexchange.com/2.2/questions?pagesize=100&order=desc&sort=creation&tagged=neo4j&site=stackoverflow&filter=!5-i6Zw8Y)4W7vpy91PMYsKM-k9yzEsSC1_Uxlf" AS url
CALL apoc.load.json(url) YIELD value

UNWIND value.items AS q
MATCH (question:Question {id: q.question_id})
MERGE (owner:User {id:q.owner.user_id})
  ON CREATE SET owner.display_name = q.owner.display_name
MERGE (owner)-[:ASKED]->(question)
"""
graph.run(query).to_data_frame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query = """
WITH "https://api.stackexchange.com/2.2/questions?pagesize=100&order=desc&sort=creation&tagged=neo4j&site=stackoverflow&filter=!5-i6Zw8Y)4W7vpy91PMYsKM-k9yzEsSC1_Uxlf" AS url
CALL apoc.load.json(url) YIELD value

UNWIND value.items AS q
MATCH (question:Question {id: q.question_id})

FOREACH (tagName IN q.tags | MERGE (tag:Tag {name:tagName}) MERGE (question)-[:TAGGED]->(tag))
FOREACH (a IN q.answers |
   MERGE (question)<-[:ANSWERED]-(answer:Answer {id:a.answer_id})
   MERGE (answerer:User {id:a.owner.user_id}) ON CREATE SET answerer.display_name = a.owner.display_name
   MERGE (answer)<-[:PROVIDED]-(answerer)
)
"""
graph.run(query).to_data_frame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Create Constraints: Let's create some constraints to make sure we don't import duplicate data:

# %%
display(graph.run("CREATE CONSTRAINT on (q:Question) ASSERT q.id IS UNIQUE;").stats())
display(graph.run("CREATE CONSTRAINT on (t:Tag) ASSERT t.name IS UNIQUE;").stats())
display(graph.run("CREATE CONSTRAINT on (u:User) ASSERT u.id IS UNIQUE;").stats())
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 display(graph.run("CREATE CONSTRAINT on (q:Question) ASSERT q.id IS UNIQUE;").stats())
#       2 display(graph.run("CREATE CONSTRAINT on (t:Tag) ASSERT t.name IS UNIQUE;").stats())
#       3 display(graph.run("CREATE CONSTRAINT on (u:User) ASSERT u.id IS UNIQUE;").stats())
#
# File c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages\py2neo\database.py:405, in Graph.run(self, cypher, parameters, **kwparameters)
#     395 def run(self, cypher, parameters=None, **kwparameters):
#     396     """ Run a single read/write query within an auto-commit
#     397     :class:`~py2neo.Transaction`.
#     398
#    (...)
#     403     :return:
#     404     """
# --> 405     return self.auto().run(cypher, parameters, **kwparameters)
#
# File c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages\py2neo\database.py:992, in Transaction.run(self, cypher, parameters, **kwparameters)
#     988     else:
#     989         result = self._connector.auto_run(cypher, parameters,
#     990                                           graph_name=self.graph.name,
#     991                                           readonly=self.readonly)
# --> 992     self._connector.pull(result, -1)
#     993     return Cursor(result, hydrant)
#     994 finally:
#
# File c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages\py2neo\client\__init__.py:1434, in Connector.pull(self, result, n)
#    1432 cx = self._reacquire(result.transaction)
#    1433 try:
# -> 1434     cx.pull(result, n=n)
#    1435 except (ConnectionUnavailable, ConnectionBroken):
#    1436     self.prune(cx.profile)
#
# File c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages\py2neo\client\bolt.py:1001, in Bolt4x0.pull(self, result, n, capacity)
#     998     raise_from(ConnectionBroken("Transaction broken by disconnection "
#     999                                 "during pull"), error)
#    1000 else:
# -> 1001     self._audit(self._transaction)
#    1002     return response
#
# File c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages\py2neo\client\bolt.py:810, in Bolt1._audit(self, task)
#     808     return
#     809 try:
# --> 810     task.audit()
#     811 except Neo4jError:
#     812     self.reset(force=True)
#
# File c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages\py2neo\client\bolt.py:1140, in ItemizedTask.audit(self)
#    1138 def audit(self):
#    1139     for item in self._items:
# -> 1140         item.audit()
#
# File c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages\py2neo\client\bolt.py:1140, in ItemizedTask.audit(self)
#    1138 def audit(self):
#    1139     for item in self._items:
# -> 1140         item.audit()
#
# File c:\users\ruhit\appdata\local\programs\python\python38\lib\site-packages\py2neo\client\bolt.py:1303, in BoltResponse.audit(self)
#    1301 if self._failure:
#    1302     self.set_ignored()
# -> 1303     raise self._failure
#
# ClientError: [Schema.EquivalentSchemaRuleAlreadyExists] An equivalent constraint already exists, 'Constraint( id=4, name='constraint_b8063308', type='UNIQUENESS', schema=(:Question {id}), ownedIndex=3 )'.

# %% [markdown]
# Larger import (10 Pages)

# %%
query = """
UNWIND range(1,10) as page
WITH "https://api.stackexchange.com/2.2/questions?page="+page+"&pagesize=100&order=desc&sort=creation&tagged=neo4j&site=stackoverflow&filter=!5-i6Zw8Y)4W7vpy91PMYsKM-k9yzEsSC1_Uxlf" AS url
CALL apoc.load.json(url) YIELD value

UNWIND value.items AS q

MERGE (question:Question {id:q.question_id})
  ON CREATE SET question.title = q.title, question.share_link = q.share_link, question.favorite_count = q.favorite_count, question.creation_date = q.creation_date
"""
graph.run(query).to_data_frame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query = """
UNWIND range(1,10) as page
WITH "https://api.stackexchange.com/2.2/questions?page="+page+"&pagesize=100&order=desc&sort=creation&tagged=neo4j&site=stackoverflow&filter=!5-i6Zw8Y)4W7vpy91PMYsKM-k9yzEsSC1_Uxlf" AS url
CALL apoc.load.json(url) YIELD value

UNWIND value.items AS q
MATCH (question:Question {id:q.question_id})

MERGE (owner:User {id:coalesce(q.owner.user_id,'deleted')})
  ON CREATE SET owner.display_name = q.owner.display_name
MERGE (owner)-[:ASKED]->(question)
"""
graph.run(query).to_data_frame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query = """
UNWIND range(1,10) as page
WITH "https://api.stackexchange.com/2.2/questions?page="+page+"&pagesize=100&order=desc&sort=creation&tagged=neo4j&site=stackoverflow&filter=!5-i6Zw8Y)4W7vpy91PMYsKM-k9yzEsSC1_Uxlf" AS url
CALL apoc.load.json(url) YIELD value

UNWIND value.items AS q
MATCH (question:Question {id:q.question_id})

FOREACH (tagName IN q.tags | MERGE (tag:Tag {name:tagName}) MERGE (question)-[:TAGGED]->(tag))
FOREACH (a IN q.answers |
   MERGE (question)<-[:ANSWERED]-(answer:Answer {id:a.answer_id})
   MERGE (answerer:User {id:coalesce(a.owner.user_id,'deleted')}) ON CREATE SET answerer.display_name = a.owner.display_name
   MERGE (answer)<-[:PROVIDED]-(answerer)
)
"""
graph.run(query).to_data_frame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Section-2: EDA

# %% [markdown]
# Schema visualization

# %%
graph.run("CALL db.schema.visualization()").data()
# Out:
# [{'nodes': [Node('Answer', constraints=[], indexes=[], name='Answer'),
#    Node('User', constraints=["Constraint( id=8, name='constraint_c97e0a9f', type='UNIQUENESS', schema=(:User {id}), ownedIndex=7 )"], indexes=[], name='User'),
#    Node('Question', constraints=["Constraint( id=4, name='constraint_b8063308', type='UNIQUENESS', schema=(:Question {id}), ownedIndex=3 )"], indexes=[], name='Question'),
#    Node('Tag', constraints=["Constraint( id=6, name='constraint_cfb24e60', type='UNIQUENESS', schema=(:Tag {name}), ownedIndex=5 )"], indexes=[], name='Tag')],
#   'relationships': [TAGGED(Node(), Node()),
#    ASKED(Node(), Node()),
#    ANSWERED(Node(), Node()),
#    PROVIDED(Node(), Node())]}]

# %% [markdown]
# No of nodes per label

# %%
result = {"label": [], "count": []}
for label in graph.run("CALL db.labels()").to_series():
    query = f"MATCH (:`{label}`) RETURN count(*) as count"
    count = graph.run(query).to_data_frame().iloc[0]['count']
    result["label"].append(label)
    result["count"].append(count)
nodes_df = pd.DataFrame(data=result)
nodes_df.sort_values("count")
# Out:
#       label  count
# 2       Tag    394
# 1      User    799
# 3    Answer    890
# 0  Question   1000

# %% [markdown]
# Visualization using matplotlib

# %%
nodes_df.plot(kind='bar', x='label', y='count', legend=None, title="Node Cardinalities")
plt.yscale("log")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# List of types of relationships

# %%
result = {"Relationship Type": [], "Count": []}
for relationship_type in graph.run("CALL db.relationshipTypes()").to_series():
    query = f"MATCH ()-[:`{relationship_type}`]->() RETURN count(*) as Count"
    count = graph.run(query).to_data_frame().iloc[0]['Count']
    result["Relationship Type"].append(relationship_type)
    result["Count"].append(count)
rels_df = pd.DataFrame(data=result)
rels_df.sort_values("Count")
# Out:
#   Relationship Type  Count
# 2          ANSWERED    890
# 3          PROVIDED    890
# 0             ASKED   1000
# 1            TAGGED   2848

# %% [markdown]
# Visualization of the Relationship count result

# %%
rels_df.plot(kind='bar', x='Relationship Type', y='Count', legend=None, title="Relationship Cardinalities")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# List of labels

# %%
query = """ MATCH (n) RETURN labels(n) as Label, count(*) as Count; """
result = pd.DataFrame(graph.run(query).to_data_frame())
result_dict = {'Label': [], 'Count': []}
result['Label'] = [line for line in result['Label'].str[0]]
result['Count'] = [line for line in result['Count']]
result_df = pd.DataFrame(result)
result_df
# Out:
#       Label  Count
# 0  Question   1000
# 1      User    799
# 2       Tag    394
# 3    Answer    890

# %% [markdown]
# Visualization of Label vs Count

# %%
result_df.plot(x='Label', y='Count', kind='bar', title='Label vs Count')
# Out:
# <Axes: title={'center': 'Label vs Count'}, xlabel='Label'>

# %% [markdown]
# Top 15 Tagged items and their counts

# %%
query = """ MATCH ()-[:TAGGED]->(t:Tag) RETURN t.name as `Tagged Name`,count(*) as Posts order by Posts desc limit 15;"""
result = pd.DataFrame(graph.run(query).to_data_frame())
result
# Out:
#            Tagged Name  Posts
# 0                neo4j   1000
# 1               cypher    463
# 2      graph-databases     80
# 3           neo4j-apoc     78
# 4               python     65
# 5    spring-data-neo4j     57
# 6                 java     45
# 7             database     40
# 8                graph     36
# 9           memgraphdb     27
# 10             node.js     23
# 11         spring-boot     22
# 12  graph-data-science     21
# 13             graphql     21
# 14          opencypher     20

# %% [markdown]
# Visualization of Tag vs Post

# %%
result.plot(x='Tagged Name', y='Posts', kind='bar', title='Tag vs Post')
# Out:
# <Axes: title={'center': 'Tag vs Post'}, xlabel='Tagged Name'>

# %% [markdown]
# Top ten users asking questions

# %%
query = """MATCH (User:User)-[:ASKED]->() RETURN User.display_name as Name, count(*) as Posts ORDER by Posts desc limit 10;"""
result = pd.DataFrame(graph.run(query).to_data_frame())
result
# Out:
#                       Name  Posts
# 0                alexanoid     39
# 1                    drdot     28
# 2                 Vincenzo     10
# 3           le Minh Nguyen     10
# 4                 JAMSHAID      9
# 5                   SteveS      8
# 6  daylightisminetocommand      7
# 7                 MichaelE      6
# 8               Lakeside52      6
# 9     Christos Grigoriadis      6

# %% [markdown]
# Visualiztion of Top ten users vs posts

# %%
result.plot(x='Name', y='Posts', kind='bar', title='User vs Posts')
# Out:
# <Axes: title={'center': 'User vs Posts'}, xlabel='Name'>

# %% [markdown]
# Top ten users answering

# %%
query = """MATCH (User:User)-[:PROVIDED]->() RETURN User.display_name as Name, count(*) as Posts ORDER by Posts desc limit 10;"""
result = pd.DataFrame(graph.run(query).to_data_frame())
result
# Out:
#                    Name  Posts
# 0            jose_bacoy    160
# 1       Charchit Kapoor    148
# 2              cybersam     68
# 3        Tomaž Bratanič     49
# 4            Graphileon     47
# 5        Michael Hunger     36
# 6  Christophe Willemsen     29
# 7          William Lyon     18
# 8          Vincent Rupp     14
# 9          nimrod serok     13

# %% [markdown]
# Visualization of top ten users answering posts

# %%
result.plot(x='Name', y='Posts', kind='bar', title='Top ten users answering posts')
# Out:
# <Axes: title={'center': 'Top ten users answering posts'}, xlabel='Name'>

# %% [markdown]
# Top days for answering questions

# %%
query = """MATCH (q:Question) RETURN apoc.date.format(q.creation_date,'s','EE') as Day, count(*) as Frequency ORDER BY Frequency desc;"""
result = pd.DataFrame(graph.run(query).to_data_frame())
result
# Out:
#    Day  Frequency
# 0  Wed        181
# 1  Tue        177
# 2  Thu        170
# 3  Mon        153
# 4  Fri        132
# 5  Sun        100
# 6  Sat         87

# %% [markdown]
# Visualization of top ten days for answering questions

# %%
result.plot(x='Day', y='Frequency', kind='bar', title='Top ten days for answering questions')
# Out:
# <Axes: title={'center': 'Top ten days for answering questions'}, xlabel='Day'>

# %% [markdown]
# Top ten tags for the user: "cybersam"

# %%
query = """MATCH (u:User)-[:PROVIDED]->()-[:ANSWERED]->()-[:TAGGED]->(t:Tag) WHERE u.display_name = "cybersam" RETURN t.name as `Tag`,count(*) as Posts order by Posts desc limit 10;"""
result = pd.DataFrame(graph.run(query).to_data_frame())
result
# Out:
#                Tag  Posts
# 0            neo4j     68
# 1           cypher     43
# 2       opencypher      9
# 3       memgraphdb      8
# 4       neo4j-apoc      8
# 5  graph-databases      7
# 6         database      2
# 7    shortest-path      2
# 8     neo4j-driver      2
# 9           python      2

# %% [markdown]
# Visualization for top ten tags for the user: "cybersam"

# %%
result.plot(x='Tag', y='Posts', kind='bar', title='Top ten tags for the user: "cybersam"')
# Out:
# <Axes: title={'center': 'Top ten tags for the user: "cybersam"'}, xlabel='Tag'>

# %% [markdown]
# Tags for unanswered questions

# %%
query = """MATCH (q:Question)-[:TAGGED]->(t:Tag) WHERE not t.name IN ['neo4j','cypher'] and not (q)<-[:ANSWERED]-() RETURN t.name as Tag, count(*) as Posts ORDER BY Posts desc LIMIT 10;""" 
result = pd.DataFrame(graph.run(query).to_data_frame())
result
# Out:
#                  Tag  Posts
# 0               java     23
# 1  spring-data-neo4j     23
# 2             python     20
# 3    graph-databases     19
# 4        spring-boot     15
# 5           database     14
# 6             spring     12
# 7            graphql     10
# 8         neo4j-apoc     10
# 9              graph      9

# %% [markdown]
# Visualization of tags for unanswered questions

# %%
result.plot(x='Tag', y='Posts', kind='bar', title='Tags for unanswered questions')
# Out:
# <Axes: title={'center': 'Tags for unanswered questions'}, xlabel='Tag'>

# %% [markdown]
# Tag correlations

# %%
query = """MATCH (t1:Tag)<-[:TAGGED]-()-[:TAGGED]->(t2:Tag) WHERE id(t1) < id(t2) and t1.name <> 'neo4j' and t2.name <> 'neo4j' RETURN t1.name as `Tag-1`, t2.name as `Tag-2`,count(*) as Frequency ORDER BY Frequency desc LIMIT 10;""" 
result = pd.DataFrame(graph.run(query).to_data_frame())
result
# Out:
#                Tag-1              Tag-2  Frequency
# 0             cypher    graph-databases         47
# 1             cypher         neo4j-apoc         45
# 2             cypher         memgraphdb         23
# 3             cypher         opencypher         18
# 4             cypher              graph         18
# 5             python             cypher         17
# 6         memgraphdb         opencypher         16
# 7               java  spring-data-neo4j         16
# 8             cypher           database         16
# 9  spring-data-neo4j             spring         14

# %% [markdown]
# User engagement for User "InverseFalcon"

# %%
query = """MATCH (t1:Tag)<-[:TAGGED]-()-[:TAGGED]->(t2:Tag)
WHERE id(t1) < id(t2) and t1.name <> 'neo4j' and t2.name <> 'neo4j'
WITH t1, t2,count(*) as freq  where freq > 3
RETURN t1,t2, apoc.create.vRelationship(t1,'OCCURRED',{freq:freq},t2) as rel;""" 
result = pd.DataFrame(graph.run(query).to_data_frame())
result
# Out:
#                                  t1                               t2  \
# 0                {'name': 'python'}               {'name': 'cypher'}
# 1                {'name': 'cypher'}           {'name': 'memgraphdb'}
# 2                {'name': 'cypher'}           {'name': 'neo4j-apoc'}
# 3                {'name': 'python'}               {'name': 'py2neo'}
# 4                {'name': 'cypher'}            {'name': 'neo4j-ogm'}
# 5               {'name': 'graphql'}     {'name': 'neo4j-graphql-js'}
# 6                {'name': 'cypher'}             {'name': 'database'}
# 7                {'name': 'python'}                 {'name': 'json'}
# 8                {'name': 'cypher'}         {'name': 'graph-theory'}
# 9                {'name': 'cypher'}                 {'name': 'java'}
# 10               {'name': 'cypher'}    {'name': 'spring-data-neo4j'}
# 11            {'name': 'neo4j-ogm'}    {'name': 'spring-data-neo4j'}
# 12                 {'name': 'java'}    {'name': 'spring-data-neo4j'}
# 13           {'name': 'memgraphdb'}      {'name': 'graph-databases'}
# 14               {'name': 'cypher'}      {'name': 'graph-databases'}
# 15             {'name': 'database'}      {'name': 'graph-databases'}
# 16           {'name': 'neo4j-apoc'}      {'name': 'graph-databases'}
# 17      {'name': 'graph-databases'}           {'name': 'opencypher'}
# 18           {'name': 'memgraphdb'}           {'name': 'opencypher'}
# 19               {'name': 'cypher'}           {'name': 'opencypher'}
# 20               {'name': 'cypher'}                {'name': 'graph'}
# 21           {'name': 'neo4j-apoc'}                {'name': 'graph'}
# 22               {'name': 'python'}  {'name': 'neo4j-python-driver'}
# 23               {'name': 'cypher'}  {'name': 'neo4j-python-driver'}
# 24               {'name': 'cypher'}                {'name': 'nosql'}
# 25               {'name': 'cypher'}   {'name': 'query-optimization'}
# 26               {'name': 'cypher'}           {'name': 'redisgraph'}
# 27    {'name': 'spring-data-neo4j'}          {'name': 'spring-boot'}
# 28                 {'name': 'java'}          {'name': 'spring-boot'}
# 29                 {'name': 'java'}               {'name': 'spring'}
# 30    {'name': 'spring-data-neo4j'}               {'name': 'spring'}
# 31          {'name': 'spring-boot'}               {'name': 'spring'}
# 32               {'name': 'cypher'}                 {'name': 'apoc'}
# 33    {'name': 'spring-data-neo4j'}          {'name': 'spring-data'}
# 34                 {'name': 'java'}          {'name': 'spring-data'}
# 35               {'name': 'spring'}          {'name': 'spring-data'}
# 36               {'name': 'cypher'}   {'name': 'graph-data-science'}
# 37      {'name': 'graph-databases'}   {'name': 'graph-data-science'}
# 38               {'name': 'cypher'}              {'name': 'node.js'}
# 39               {'name': 'cypher'}          {'name': 'performance'}
# 40               {'name': 'cypher'}                  {'name': 'csv'}
# 41               {'name': 'python'}              {'name': 'fastapi'}
# 42                 {'name': '.net'}                   {'name': 'c#'}
# 43          {'name': 'neo4jclient'}                   {'name': 'c#'}
# 44  {'name': 'neo4j-python-driver'}           {'name': 'python-3.x'}
# 45               {'name': 'cypher'}           {'name': 'python-3.x'}
# 46               {'name': 'python'}           {'name': 'python-3.x'}
# 47               {'name': 'cypher'}                {'name': 'nodes'}
# 48               {'name': 'docker'}       {'name': 'docker-compose'}
# 49               {'name': 'cypher'}               {'name': 'lucene'}
# 50               {'name': 'cypher'}           {'name': 'javascript'}
# 51               {'name': 'cypher'}     {'name': 'full-text-search'}
# 52           {'name': 'javascript'}               {'name': 'neovis'}
# 53                {'name': 'scala'}         {'name': 'apache-spark'}
#
#              rel
# 0   {'freq': 17}
# 1   {'freq': 23}
# 2   {'freq': 45}
# 3   {'freq': 11}
# 4    {'freq': 5}
# 5   {'freq': 10}
# 6   {'freq': 16}
# 7    {'freq': 4}
# 8    {'freq': 8}
# 9    {'freq': 9}
# 10   {'freq': 8}
# 11   {'freq': 7}
# 12  {'freq': 16}
# 13   {'freq': 9}
# 14  {'freq': 47}
# 15   {'freq': 8}
# 16   {'freq': 4}
# 17   {'freq': 7}
# 18  {'freq': 16}
# 19  {'freq': 18}
# 20  {'freq': 18}
# 21   {'freq': 6}
# 22   {'freq': 7}
# 23   {'freq': 4}
# 24   {'freq': 4}
# 25  {'freq': 11}
# 26   {'freq': 4}
# 27  {'freq': 11}
# 28   {'freq': 8}
# 29   {'freq': 8}
# 30  {'freq': 14}
# 31   {'freq': 4}
# 32   {'freq': 7}
# 33  {'freq': 11}
# 34   {'freq': 7}
# 35   {'freq': 6}
# 36   {'freq': 8}
# 37   {'freq': 6}
# 38   {'freq': 5}
# 39   {'freq': 8}
# 40   {'freq': 5}
# 41   {'freq': 4}
# 42   {'freq': 7}
# 43   {'freq': 4}
# 44   {'freq': 4}
# 45   {'freq': 4}
# 46   {'freq': 6}
# 47   {'freq': 5}
# 48   {'freq': 4}
# 49   {'freq': 4}
# 50   {'freq': 4}
# 51   {'freq': 4}
# 52   {'freq': 4}
# 53   {'freq': 5}

# %% [markdown]
# ![graph.png](attachment:graph.png)

# %% [markdown]
# # Section-3: Applying Graph Algorithm

# %% [markdown]
# Computing Betweenness Centrality Algorithm

# %%
graph.run("""
CALL gds.betweenness.write('myGraph', { writeProperty: 'betweenness' })
YIELD centralityDistribution, nodePropertiesWritten
RETURN centralityDistribution.min AS minimumScore, centralityDistribution.mean AS meanScore, nodePropertiesWritten;
""").to_data_frame()
# Out:
#    minimumScore  meanScore  nodePropertiesWritten
# 0         0.000      0.000                    997

# %%
Computing Clossness

# %%
graph.run("""
CALL gds.alpha.closeness.write({
  nodeProjection: 'Question',
  relationshipProjection: 'TAGGED',
  writeProperty: 'closeness'
}) YIELD nodes, writeProperty;
""").to_data_frame()
# Out:
#    nodes writeProperty
# 0   1000     closeness

# %%
graph.run("""
CALL gds.alpha.closeness.stream({
  nodeProjection: 'Question',
  relationshipProjection: 'TAGGED',
  improved:true 
})
YIELD nodeId, centrality
RETURN gds.util.asNode(nodeId).id AS user, centrality
ORDER BY centrality DESC;
""").to_data_frame()
# Out:
#          user  centrality
# 0    76024415       0.000
# 1    76017666       0.000
# 2    76014286       0.000
# 3    76013293       0.000
# 4    76012714       0.000
# ..        ...         ...
# 995  75143948       0.000
# 996  75132155       0.000
# 997  75127693       0.000
# 998  75122843       0.000
# 999  75102544       0.000
#
# [1000 rows x 2 columns]

# %%
graph.run("""
CALL gds.alpha.closeness.harmonic.stream({
  nodeProjection: 'Question',
  relationshipProjection: 'TAGGED'
})
YIELD nodeId, centrality
RETURN gds.util.asNode(nodeId).id AS user, centrality
ORDER BY centrality DESC
;
""").to_data_frame()
# Out:
#          user  centrality
# 0    76024415       0.000
# 1    76017666       0.000
# 2    76014286       0.000
# 3    76013293       0.000
# 4    76012714       0.000
# ..        ...         ...
# 995  75143948       0.000
# 996  75132155       0.000
# 997  75127693       0.000
# 998  75122843       0.000
# 999  75102544       0.000
#
# [1000 rows x 2 columns]

# %%
Computing PageRank

# %%
graph.run("""
CALL gds.pageRank.write('myGraph', {
  maxIterations: 20,
  dampingFactor: 0.85,
  writeProperty: 'pagerank'
})
YIELD nodePropertiesWritten, ranIterations;
""").to_data_frame()
# Out:
#    nodePropertiesWritten  ranIterations
# 0                    997              1
